# %% [markdown]
# # Improvement of Acute Lymphoblastic Leukaemia Classification by Using Convolutional Neural Network Methodology With Squeeze and Excitation Networks

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import numpy as np

# %%
model = tf.keras.models.load_model('.../squeeze_model_original_4.h5')
img = tf.keras.utils.load_img('.../.jpg')
img = tf.keras.utils.img_to_array(img)
img = np.expand_dims(img, axis = 0)
img = img/255

# %%
categories = ['Benign','Early','Pre','Pro']
classes = model.predict(img)
classes = np.argmax(classes,axis=1)
print ('Class:', categories[int(classes)])
print (classes)
# Out:
# 1/1 [==============================] - 7s 7s/step
# Class: Benign
# [0]
